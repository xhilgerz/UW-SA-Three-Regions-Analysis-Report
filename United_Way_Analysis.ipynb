# %% [markdown]
# <a href="https://colab.research.google.com/github/xhilgerz/UW-SA-Three-Regions-Analysis-Report/blob/main/United_Way_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This prints all the options present in the interactions InteractionOption_CallType

import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
basicpath = '/content/drive/MyDrive/United Way Project/'
filepath = basicpath + '211 Interactions_Three Regions_thru 2025.csv'

# %%
data = pd.read_csv(filepath)
data
# Out:
# /tmp/ipykernel_2735/2420190847.py:1: DtypeWarning: Columns (6,7,8,13,14,15,16,34,40,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filepath)
#                               Table Names_Interaction Tab  \
# 0       statewidecallexport-november2024.xlsx/Interaction
# 1       statewidecallexport-november2024.xlsx/Interaction
# 2       statewidecallexport-november2024.xlsx/Interaction
# 3       statewidecallexport-november2024.xlsx/Interaction
# 4       statewidecallexport-november2024.xlsx/Interaction
# ...                                                   ...
# 378389           statewidecallexport-july2025.xlsx/Client
# 378390           statewidecallexport-july2025.xlsx/Client
# 378391           statewidecallexport-july2025.xlsx/Client
# 378392           statewidecallexport-july2025.xlsx/Client
# 378393           statewidecallexport-july2025.xlsx/Client
#
# ...
